# %%
data <- read.csv('total_evaluation_List.csv')
data
# Out:
#     happy.Easy.Random.1.803999900817871.arnout
# 1   sad Easy Random 2.185999870300293 arnout
# 2   sad Easy Random 1.1089999675750732 arnout
# 3   sad Easy Random 2.199000120162964 arnout
# 4   happy Medium IMS 1.5989999771118164 arnout
# 5   happy Easy IMS 1.3519999980926514 arnout
# 6   sad Easy IMS 1.2649998664855957 arnout
# 7   sad Easy IMS 0.8469998836517334 arnout
# 8   angry Hard Random 1.062999963760376 arnout
# 9   angry Hard Random 0.9570000171661377 arnout
# 10  sad Hard Random 1.3870000839233398 arnout
# 11  sad Medium Random 1.440999984741211 arnout
# 12  sad Medium Random 1.8940000534057617 arnout
# 13  sad Hard IMS 1.0109999179840088 arnout
# 14  angry Hard IMS 0.8090000152587891 arnout
# 15  happy Easy Random 0.8460001945495605 hirad
# 16  happy Easy Random 1.7009999752044678 hirad
# 17  happy Easy Random 1.4059998989105225 hirad
# 18  sad Medium IMS 1.563999891281128 hirad
# 19  happy Easy IMS 1.1150000095367432 hirad
# ...

# %%
md <- lm()
